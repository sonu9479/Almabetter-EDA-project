# %% [markdown]
# <a href="https://colab.research.google.com/github/sonu9479/Almabetter-EDA-project/blob/main/Vivek_Singh_cohort_london_EDA_on_Hotel_Booking_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -  <B> Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Name - Vivek Singh**

# %% [markdown]
# # **Project Summary -**
#
#
# ## <b>The project is on hotel booking analysis.For two types of hotels,
#  City Hotel and Resort Hotel.
#
#   In this dataset contains total rows  119390 and 32 columns.In this we divide data manipulation workflow in three category
#
#    Data Collection.
#
#    Data cleaning and manipulation.
#
#    EDA(Exploratory Data Analysis).
#
#   As Further moved i.e Data collections first step to find different columns which is done by coding Head(), tail(), info(), describe(), columns() and some others method used for data collections, some of the columns name is updated here i.e hotel,is_canceled,lead_time,arrival_date_year,arrival_date_month,arrival_date_week_number,arrival_date_day_of_month,stays_in_weekend_nights.As we further moved we find unique value of each columns and generate a list in tabular form and also check the dataset type of each column find some columns not in accurate data types which correct it later done  in Data cleaning part and as well as duplicates data items must be removed as we find duplicates items equal  to 87396 which is dropped from dataset later.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/sonu9479/Almabetter-EDA-project

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# ## The hotel industry is an important sector of the global economy, with millions of bookings made every day. However, hotel booking cancellations have become a significant issue for hoteliers, as they result in lost revenue and wasted resources. In this context, exploratory data analysis (EDA) can provide insights into the factors that influence hotel booking cancellations.
#
# ## The objective of this EDA is to analyze the data related to hotel bookings and cancellations to identify patterns and trends that can help hotel managers to make data-driven decisions. Specifically, this EDA will focus on the following questions:
#
# ## 1) What are the main factors that influence hotel booking cancellations?
# ## 2) How do these factors vary across different regions, seasons, and types of hotels?
# ## 3) How can hotel managers use this information to improve their revenue management strategies?
# ##To answer these questions, we will use a dataset that contains information about hotel bookings, including the type of hotel, the booking date, the check-in and check-out dates, the number of guests, the number of rooms, and the booking status (confirmed or cancelled). We will perform data cleaning and pre-processing, exploratory data analysis, and data visualization to gain insights into the factors that influence hotel booking cancellations.

# %% [markdown]
# ## **Business Objective:**

# %% [markdown]
# ###Explore and analyze the data to discover important factors that govern the bookings.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
#@title
# Importing Libraries
from io import IncrementalNewlineDecoder
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from datetime import datetime
import ast

# Set maximum columns to be display in datafram as 36
pd.set_option("display.max_columns", 36)
plt.style.use('seaborn')

# Setting fontsizes,fontweight,label weight for lebels,titles.
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["axes.titlesize"] = 25
plt.rcParams["axes.titleweight"] = 'bold'
plt.rcParams['xtick.labelsize']=15
plt.rcParams['ytick.labelsize']=15
plt.rcParams["axes.labelsize"] = 20
plt.rcParams["legend.fontsize"] = 15
plt.rcParams["legend.title_fontsize"] = 15
# Out:
# <ipython-input-2-d7991dd394ae>:14: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
# Mounting drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#csv file location
file_path= "/content/drive/MyDrive/Capstone Projects/Hotel Bookings.csv"

# %% [markdown]
# Dataset link: https://drive.google.com/file/d/11KDe-fduU41TSZ4VFLsljxH7hr1DF4d6/view?usp=share_link

# %% [markdown]
# ### Dataset Loading

# %%
# reading csv file
dataset = pd.read_csv(file_path)

# %%
# Making copy of original database
dataset1 = dataset.copy()

# %% [markdown]
# ### Dataset First View

# %%
# Dataset view
dataset1
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
#checking the shape ( rows and column numbers)
print(f"The number of rows in the dataset is {dataset1.shape[0]}.")
print(f"The number of columns in the dataset is {dataset1.shape[1]}.")
# Out:
# The number of rows in the dataset is 119390.
# The number of columns in the dataset is 32.

# %% [markdown]
# ### Dataset Information

# %%
#looking for the data types non null entries
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
#looking at the min, max values,mean values etc. NAN values for mean,25% ,50%,75%,max indicates those are categorical columns.
dataset1.describe(include ='all')
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Counting values of duplicate values in the dataset.
dataset1.duplicated().value_counts()

# Dropping the duplicate values from dataset.
dataset1.drop_duplicates(inplace = True)

# Finding the values of unique values from dataset.
print(f"The number of unique values in the rows is {dataset1.shape[0]}")
# Out:
# The number of unique values in the rows is 87396

# %%
# Resetting indices.
dataset1.reset_index()
# Out:
#         index         hotel  is_canceled  lead_time  arrival_date_year  \
# 0           0  Resort Hotel            0        342               2015
# 1           1  Resort Hotel            0        737               2015
# 2           2  Resort Hotel            0          7               2015
# 3           3  Resort Hotel            0         13               2015
# 4           4  Resort Hotel            0         14               2015
# ...       ...           ...          ...        ...                ...
# 87391  119385    City Hotel            0         23               2017
# 87392  119386    City Hotel            0        102               2017
# 87393  119387    City Hotel            0         34               2017
# 87394  119388    City Hotel            0        109               2017
# 87395  119389    City Hotel            0        205               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

missing_values = dataset1.isna().sum().sort_values(ascending = False)[:6]
missing_values
# Out:
# company               82137
# agent                 12193
# country                 452
# children                  4
# reserved_room_type        0
# assigned_room_type        0
# dtype: int64

# %%
# Visualizing the missing values
plt.figure(figsize = (30,15))
sns.heatmap(dataset1.isna(), cbar=False, yticklabels=False ,cmap='plasma')
plt.xlabel("Name Of Columns")
plt.title("Places of missing values in column")
# Out:
# Text(0.5, 1.0, 'Places of missing values in column')

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# So we Have Null values in columns- Company, agent, Country,children.
#
# 1. for company and agent I will fill the Missing values with 0
# 2. for country I will fill Missing values with object 'Others'. ( assuming while collecting data country was not found so user selected the 'Others' option.)
# 3. AS the count of missing values in Children Column is only 4, so we can replace with 0 considering no childrens.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
dataset1.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
dataset.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# ### Data Description:
#
# 1. **hotel** : *Hotel(Resort Hotel or City Hotel)*
#
# 2. **is_canceled** : *Value indicating if the booking was canceled (1) or not (0)*
#
# 3. **lead_time** :* Number of days that elapsed between the entering date of the booking into the PMS and the arrival date*
#
# 4. **arrival_date_year** : *Year of arrival date*
#
# 5. **arrival_date_month** : *Month of arrival date*
#
# 6. **arrival_date_week_number** : *Week number of year for arrival date*
#
# 7. **arrival_date_day_of_month** : *Day of arrival date*
#
# 8. **stays_in_weekend_nights** : *Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel*
#
# 9. **stays_in_week_nights** : *Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel*
#
# 10. **adults** : *Number of adults*
#
# 11. **children** : *Number of children*
#
# 12. **babies** : *Number of babies*
#
# 13. **meal** : *Type of meal booked. Categories are presented in standard hospitality meal packages:*
#
# 14. **country** : *Country of origin.`*
#
# 15. **market_segment** : *Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”*
#
# 16. **distribution_channel** : *Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”*
#
# 17. **is_repeated_guest** : *Value indicating if the booking name was from a repeated guest (1) or not (0)*
#
# 18. **previous_cancellations** : *Number of previous bookings that were cancelled by the customer prior to the current booking*
#
# 19. **previous_bookings_not_canceled** : *Number of previous bookings not cancelled by the customer prior to the current booking*
#
# 20. **reserved_room_type** : *Code of room type reserved. Code is presented instead of designation for anonymity reasons.*
#
# 21. **assigned_room_type** : *Code for the type of room assigned to the booking.*
#
# 22. **booking_changes** : *Number of changes/amendments made to the booking from the moment the booking was entered on the PMS until the moment of check-in or cancellation*
#
# 23. **deposit_type** : *Indication on if the customer made a deposit to guarantee the booking.*
#
# 24. **agent** : *ID of the travel agency that made the booking*
#
# 25. **company** : *ID of the company/entity that made the booking or responsible for paying the booking.*
#
# 26. **days_in_waiting_list** : *Number of days the booking was in the waiting list before it was confirmed to the customer*
#
# 27. **customer_type** : *Type of booking, assuming one of four categories*
#
#
# 28. **adr** : *Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights*
#
# 29. **required_car_parking_spaces** : *Number of car parking spaces required by the customer*
#
# 30. **total_of_special_requests** :* Number of special requests made by the customer (e.g. twin bed or high floor)*
#
# 31. **reservation_status** : *Reservation last status, assuming one of three categories*
# * Canceled – booking was canceled by the customer
# * Check-Out – customer has checked in but already departed
# * No-Show – customer did not check-in and did inform the hotel of the reason why
#
#
#
#
#
# 32. **reservation_status_date** : *Date at which the last status was set. This variable can be used in conjunction with the ReservationStatus to understand when was the booking canceled or when did the customer checked-out of the hotel*

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Checking Unique Values for each variable.
# print(dataset1.apply(lambda col: col.unique()))
for i in dataset1:
  if len(dataset1[i].unique()) < 30:
    print(f"The unique values for {i} are: {dataset1[i].unique()} \n")
# Out:
# The unique values for hotel are: ['Resort Hotel' 'City Hotel']
#
# The unique values for is_canceled are: [0 1]
#
# The unique values for arrival_date_year are: [2015 2016 2017]
#
# The unique values for arrival_date_month are: ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
#
# The unique values for stays_in_weekend_nights are: [ 0  1  2  4  3  6 13  8  5  7 12  9 16 18 19 10 14]
#
# The unique values for adults are: [ 2  1  3  4 40 26 50 27 55  0 20  6  5 10]
#
# The unique values for children are: [ 0.  1.  2. 10.  3. nan]
#
# The unique values for babies are: [ 0  1  2 10  9]
#
# The unique values for meal are: ['BB' 'FB' 'HB' 'SC' 'Undefined']
#
# The unique values for market_segment are: ['Direct' 'Corporate' 'Online TA' 'Offline TA/TO' 'Complementary' 'Groups'
#  'Undefined' 'Aviation']
#
# The unique values for distribution_channel are: ['Direct' 'Corporate' 'TA/TO' 'Undefined' 'GDS']
#
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make the dataset analysis ready.

missing_values
# Out:
# company               82137
# agent                 12193
# country                 452
# children                  4
# reserved_room_type        0
# assigned_room_type        0
# dtype: int64

# %% [markdown]
# ##So we Have Null values in columns- Company, agent, Country,children.
#
# ##for company and agent I will fill the Missing values with 0
# ##for country I will fill Missing values with boject 'Others'. ( assuming while collecting data country was not found so user selected the 'Others' option.)
# ##AS the count of missing values in Children Column is only 4, so we can ##replace with 0 considering no childrens.

# %%
# Replacing null values with 0
n_v_col = ['company', 'agent', 'children']
for col in n_v_col:
  dataset1[col].fillna(0,inplace = True)

# Replacing null values in country column with 'others'.
dataset1['country'].fillna("others", inplace = True)

# %%
# Checking null values again

dataset1.isnull().sum() # We can see that there is no null value left in the dataset.
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87396 non-null  object
#  1   is_canceled                     87396 non-null  int64
#  2   lead_time                       87396 non-null  int64
#  3   arrival_date_year               87396 non-null  int64
#  4   arrival_date_month              87396 non-null  object
#  5   arrival_date_week_number        87396 non-null  int64
#  6   arrival_date_day_of_month       87396 non-null  int64
#  7   stays_in_weekend_nights         87396 non-null  int64
#  8   stays_in_week_nights            87396 non-null  int64
#  9   adults                          87396 non-null  int64
#  10  children                        87396 non-null  float64
#  11  babies                          87396 non-null  int64
# ...

# %%
# We can see that 'children' and "agent" columns are float type, we need to change the data type to integer for the sake of generalization.


dataset1[['children', 'agent','company']] = dataset1[['children', 'agent','company']].astype('int64')

# %%
# Changing 'reservation_status_date' from object datatype to datetime format.


dataset1['reservation_status_date'] = pd.to_datetime(dataset1['reservation_status_date'], format = '%Y-%m-%d')

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87396 non-null  object
#  1   is_canceled                     87396 non-null  int64
#  2   lead_time                       87396 non-null  int64
#  3   arrival_date_year               87396 non-null  int64
#  4   arrival_date_month              87396 non-null  object
#  5   arrival_date_week_number        87396 non-null  int64
#  6   arrival_date_day_of_month       87396 non-null  int64
#  7   stays_in_weekend_nights         87396 non-null  int64
#  8   stays_in_week_nights            87396 non-null  int64
#  9   adults                          87396 non-null  int64
#  10  children                        87396 non-null  int64
#  11  babies                          87396 non-null  int64
# ...

# %%
#We need to create some additional columns will will be required for further analysis of our dataset.

dataset1['total_people'] = dataset1['adults'] + dataset1['babies'] + dataset1['children']   
dataset1['total_stays'] = dataset1['stays_in_weekend_nights'] + dataset1['stays_in_week_nights']   

dataset1.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2         0       0
# ...

# %%
# We have created a col for revenue using total stay * adr
dataset1['revenue'] = dataset1['total_stays'] *dataset1['adr']
dataset1['revenue']
# Out:
# 0            0.00
# 1            0.00
# 2           75.00
# 3           75.00
# 4          196.00
#            ...
# 119385     672.98
# 119386    1578.01
# 119387    1103.97
# 119388     730.80
# 119389    1360.80
# Name: revenue, Length: 87396, dtype: float64

# %%
# for understanding, from col 'is_cancelled': we will replace the value from (0,1) to not_canceled, is canceled.

dataset1['is_canceled'] = dataset1['is_canceled'].replace([0,1], ['not canceled', 'is canceled'])
dataset1['is_canceled']
# Out:
# 0         not canceled
# 1         not canceled
# 2         not canceled
# 3         not canceled
# 4         not canceled
#               ...
# 119385    not canceled
# 119386    not canceled
# 119387    not canceled
# 119388    not canceled
# 119389    not canceled
# Name: is_canceled, Length: 87396, dtype: object

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# I have done few manipulations in the Data.
#
# ----Addition of columns----
#
# I have seen that there are few columns required in Data to analysis purpose which can be evaluated from the given columns.
#
# a) Total Guests: This columns will help us to evaluate the volumes of total guest and revenue as well. We get this value by adding total no. of Adults, Children & babies.
#
# b) Total Stays: This column is the sum of weekend bookings and weekdays bookings which shows the total days booked in a booking
#
# ----Changes in data type of values in columns----
#
# a)Agent, Children and company: We checked that these columns contains float values, which is not making any sense in data as this values repreasent the count of guest & ID of agent. So we have changed the data type of these columns from 'float' to 'Integer'.
#
# ----Removed is_null values & duplicate entries----
#
# a)Before visualize any data from the data set we have to do data wrangling. For that, we have checked the null value in all the columns. After checking, when we are getting a column which has more number of null values, dropped that column by using the 'drop' method. In this way, we are dropped the 'company' column. When we are find minimal number of null values, filling thse null values with necesary values as per requirement by using .fillna().
#
# b) In the same, we have checked if there is any duplicacy in data & we found that there are few rows have duplicate data. So we have removed those row from data set by using .drop_duplicates() method.
#
# In this way, we have removed unneccesary data & make our data clean and ready to analyse.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# # **1) Which type of hotel is mostly prefered by the guests?**

# %%
# Chart - 1 visualization pie graph for most preferred hotel.
dataset1['hotel'].value_counts().plot.pie(explode = [0.05, 0.05], autopct='%1.2f%%',startangle=90, figsize = (10,10), fontsize = (15), title = 'Pie Chart for Most Prefered  Hotel',shadow = True, ylabel = '')
plt.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ## To present the data that in which hotel more booking have been done.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## Here, we found that the booking number is Higher in City Hotel which is 61.12% than Resort Hotel which is 38.87%. Hence we can say that City hotel has more consumption

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ## Yes, for both Hotels, this data making some positive business impact : -
#
# ## City Hotel :- Provided more services to attract more guest to increase more revenue.
#
# ## Resort Hotel :- Find solution to attract guest and find what city hotel did to attract guest.

# %% [markdown]
# #### Chart - 2

# %% [markdown]
# # **2) Cancellation rate on bookings.**

# %%
#Visualizing cancellation rate on bookings using pie graph.
dataset1['is_canceled'].value_counts().plot.pie(explode=[0.05, 0.05,], autopct='%1.2f%%',startangle=90, shadow=True, figsize=(10,8),fontsize=15, title = 'Cancellation rate on bookings.', ylabel = "")
plt.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ## I picked the pie chart as there are two quantities and I wanted to show the percentage comparison between them.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## Here, I found that the rate of cancelation in the overall bookings is 27.49%.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ## From the above chart we got the insight about the cancellation rate of the bookings which directly impacts the total revenue of the hotel industry, We need to find the causes of cancellation and try to minimize it as much as possible.

# %% [markdown]
# #### Chart - 3

# %% [markdown]
# # **3) Which Agent made the most bookings?**

# %%
# return highest bookings made by agents
highest_bookings= dataset1.groupby(['agent'])['agent'].agg({'count'}).reset_index().rename(columns={'count': "Most_Bookings" }).sort_values(by='Most_Bookings',ascending=False)

 # as agent 0 was NAN value and we replaced it with 0 and indicates no bookings.so droping.
highest_bookings.drop(highest_bookings[highest_bookings['agent']==0].index,inplace=True) 

# taking top 10 bookings made by agent
top_ten_highest_bookings=highest_bookings[:10]

top_ten_highest_bookings
# Out:
#      agent  Most_Bookings
# 9        9          28759
# 174    240          13028
# 14      14           3349
# 7        7           3300
# 183    250           2779
# 175    241           1644
# 27      28           1502
# 8        8           1383
# 1        1           1232
# 6        6           1117

# %%
# plotting a bar chart for Agents who made the maximum bookings.

top_ten_highest_bookings['Most_Bookings'].plot.bar(figsize = [18,8], title = 'Agents who made the maximum bookings.', color = ['b','g', 'y', 'r', 'c'])

plt.xlabel('Agent ID')

plt.ylabel('Number of bookings.')

plt.xticks(rotation = 0)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ##We have to perform a comparison of metric values across different subgroups of the datastet. From a bar chart, we can see which groups are highest or most common, and how other groups compare against the others. Since this is a fairly common task, bar charts are a fairly ubiquitous chart type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ##Agent ID no: 9 made most of the bookings

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ## From the above insights we get to know that agent no. 9 has done the greatest number of bookings, we can get an insight of agent no.9's working method and the kind of skills he aquires, We can train other agents with the help of agent no.9's expertise which can result in the improvement of the performance of agents who are not performing well.

# %% [markdown]
# #### Chart - 4

# %% [markdown]
# #**4) Most and least used distribution channels.**

# %%
#Getting the value counts of the different distribution channels.

distribution_channels = dataset1['distribution_channel'].value_counts()
distribution_channels
# Out:
# TA/TO        69141
# Direct       12988
# Corporate     5081
# GDS            181
# Undefined        5
# Name: distribution_channel, dtype: int64

# %%
#plotting a bar graph for distribution channels.

distribution_channels.plot.bar(figsize = [18,8], align = 'edge', edgecolor = 'black')

plt.title('Most and least used distribution channels')

plt.xlabel('Distribution channel')

plt.ylabel('Number of bookings.')

plt.xticks(rotation = 0)

plt.show()

# %%
# Chart - 4 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ## The following chart represent maximum volume of booking done through which channel to represnt the numbers in descending order we chose bar graph

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## As clearly seen TA/TO(Tour of Agent & Tour of operator) is highest, recommending to continue booking through TA/TO

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ## Yes this shows positive business impact.
#
# ## Higher the number of TA/TO will help to increase the revenue generation of Hotel.

# %% [markdown]
# #### Chart - 5

# %% [markdown]
# # 5) What is the Percentage of repeated guests?

# %%
# Replacing 0, 1 in 'is_repeated_guest' column to 'Not repeated', 'Repeated'.

dataset1['is_repeated_guest'] = dataset1['is_repeated_guest'].replace([0,1], ['Not repeated', 'Repeated'])

# plotting a pie chart for repeated and non repeated guests.

dataset1['is_repeated_guest'].value_counts().plot.pie(explode=(0.05,0.05),autopct='%1.1f%%',figsize=(14,8),fontsize=20, ylabel = '')

plt.title(" Percentgae (%) of repeated guests")

plt.legend()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ## To show the percentage share of repeated & non-repeated guests.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## Repeated guests are very few which only 3.9 %.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ## In order to retained the guests management should take feedbacks from guests and try to imporve the services.

# %% [markdown]
# #### Chart - 6

# %% [markdown]
# # **6) What is the percentage distribution of "Customer Type"?**

# %%
#Getting the value count for customer types.

Customer_Type = dataset1['customer_type'].value_counts()

Customer_Type
# Out:
# Transient          71986
# Transient-Party    11727
# Contract            3139
# Group                544
# Name: customer_type, dtype: int64

# %%
#Plotting a pie chart for customer type.

Customer_Type.plot.pie(explode=(0.05,0.05,.05,.05),autopct='%1.1f%%',figsize=(15,10),fontsize=20, ylabel = '')

plt.title('% Distribution of Customer Type')

plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ## To show the percentage share of booking in each month,on overall level

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Contract
#
# when the booking has an allotment or other type of contract associated to it
#
# 2. Group
#
# when the booking is associated to a group
#
# 3. Transient
#
# when the booking is not part of a group or contract, and is not associated to other transient booking
#
# 4. Transient-party
#
# when the booking is transient, but is associated to at least other transient booking

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ## Transient customer type is more whcih is 82.4 %. percentage of Booking associated by the Group is vey low.

# %% [markdown]
# #### Chart - 7

# %% [markdown]
# # **7)What is the percentage distribution of required_car_parking_spaces?**

# %%
#getting the distribution of required car parking spaces.

required_parking = dataset1['required_car_parking_spaces'].value_counts()
required_parking
# Out:
# 0    80083
# 1     7280
# 2       28
# 3        3
# 8        2
# Name: required_car_parking_spaces, dtype: int64

# %%
#plotting the distribution of required car parking spaces on a pie chart.

required_parking.plot.pie(explode = [0.05]*5, figsize = [14,8], autopct = '%1.2f%%', fontsize = 20, ylabel = '' )

plt.title('% Distribution of required car parking spaces')

plt.axis('equal')

plt.legend()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ## I chose this chart to show the percentage distribution of parking spaces.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## 91.6 % guests did not required the parking space. only 8.3 % guests required only 1 parking space.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ## As we can see that roughly 9%-10% guests need parking spaces. Keeping that in mind the hotels can efficiently manage the alloted parking space in the hotel

# %% [markdown]
# #### Chart - 8

# %% [markdown]
# # **8) Which type of food is mostly preferred by the guests?**

# %%
#writing the code for getting most preferred type of meal by guests.

meal_type = dataset1['meal'].value_counts()

meal_type
# Out:
# BB           67978
# SC            9481
# HB            9085
# Undefined      492
# FB             360
# Name: meal, dtype: int64

# %%
# plotting a bar graph to show the comparison among preferred meal type.

meal_type.plot.bar(figsize = [18,8], xlabel = 'Meal type(BB - (Bed and Breakfast),HB- (Half Board),FB- (Full Board),SC- (Self Catering))', ylabel = 'Order count', color = ['b','g','r','y'],  align = 'edge', edgecolor = 'black')

plt.title('Most preferred type of meal by guests')

plt.xticks(rotation = 0)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ## To demonstrate the number of orders as well as comparison among food order types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## 1) So the most preferred meal type by the guests is BB( Bed and Breakfast),
#
# ## 2) HB- (Half Board) and SC- (Self Catering) are equally preferred.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ## Yes, from the above insight we got to know on which meal type the hotel management should focus more and manage their inventory efficiently.

# %% [markdown]
# #### Chart - 9

# %% [markdown]
# # **9) From which country the most guests are coming?**

# %%
# Getting the countries with maximum number of guests.

country_count = dataset['country'].value_counts()[:10]

country_count
# Out:
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
# ITA     3766
# IRL     3375
# BEL     2342
# BRA     2224
# NLD     2104
# Name: country, dtype: int64

# %%
# plotting a bar graph for the countries with max. guests

country_count.plot.bar(figsize = [18,8])

plt.xlabel('Country')

plt.ylabel('Number of guests',fontsize=18)

plt.title("Number of guests from diffrent Countries")

plt.xticks(rotation = 0)

plt.show()

# %%
#importing the folium library
import folium                                # searched on google 
import plotly.express as px

# %%
basemap = folium.Map()
guests_map = px.choropleth(dataset1['country'].value_counts().reset_index()[:10],color = dataset1['country'].value_counts().reset_index()[:10]['country'], locations = dataset1['country'].value_counts().reset_index()[:10]['index'], hover_name = dataset1['country'].value_counts().reset_index()[:10]['index'])
guests_map.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ## I have used bar chart and folium library map, through the map we can understand the geographical locations easily and with bar graph we can see the distribution of bookings with exact booking numbers.
#
# ##abbreevations for countries-
#
# ## PRT- Portugal
# ##GBR- United Kingdom
# ##FRA- France
# ##ESP- Spain
# ##DEU - Germany
# ##ITA -Itlay
# ##IRL - Ireland
# ##BEL -Belgium
# ##BRA -Brazil
# # NLD-Netherlands

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## Most of the guests are coming from portugal i.e more than 25000 guests are from portugal

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ## We can do more advertising & can provide attractive offers to Portugal guests to enhance the customer volume

# %% [markdown]
# #### Chart - 10

# %% [markdown]
# # **10) Which is the most preferred room type by the customers?**

# %%
# wrinting the code for getting the most preferred room type by the customers.

most_pref_room = dataset1['assigned_room_type'].value_counts().index

most_pref_room
# Out:
# Index(['A', 'D', 'E', 'F', 'G', 'C', 'B', 'H', 'I', 'K', 'P', 'L'], dtype='object')

# %%
#plotting a graph for most preferred room type.

plt.figure(figsize = (18,8))

sns.countplot(x = dataset1['assigned_room_type'], order = most_pref_room)

#  set xlabel for the plot

plt.xlabel('Room Type')

# set y label for the plot

plt.ylabel('Count of Room Type')

#set title for the plot

plt.title("Most preferred Room type")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ## I used this graph to visualize the value count of the room types booked.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## So the most preferred Room type is "A".

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ## If we know what are the most preferred room types in the hotel we can focus on utilizing the space according to the demand, we can increase the most demanded type of rooms and minimize the least demanded type of rooms, which can result in increase of average occupancy in hotels.

# %% [markdown]
# #### Chart - 11

# %% [markdown]
# # **11)In which month most of the bookings happened?**

# %%
# Getting the month in which most of the bookings happened.
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

most_booking_month = dataset1[dataset1['is_canceled'] == 'not canceled']['arrival_date_month'].value_counts().reindex(months)
most_booking_month
# Out:
# January      3655
# February     4683
# March        5683
# April        5499
# May          5913
# June         5411
# July         6859
# August       7634
# September    5048
# October      5292
# November     3941
# December     3753
# Name: arrival_date_month, dtype: int64

# %%
# plotting a line graph for the months in which most of the bookings happened.
plt.figure(figsize = [18,8])
plt.plot(most_booking_month, c = '#4CAF50', linewidth = 5)
# set title for the plot
plt.title('Number of bookings across each month')
#set x label
plt.xlabel('Month')
#set y label
plt.ylabel('Number of bookings')
plt.grid(linewidth = 0.1, color = 'blue')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ## I picked the line graph as i had to show information that changes over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## July and August months had the most Bookings. Summer vaccation can be the reason for the bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ## July and August have the maximum bookings, hotels should maximize the hotel staff in those months for better management and customer handling, in other less populated months we can minimize hotel staff for cost cutting. In less populated months we should provide lucrative offers and discounts to get customers as they will have a wide of choice in different hotels as many will be vacant due to off season.

# %% [markdown]
# #### Chart - 12

# %% [markdown]
# # **12) Hotel wise revenue.**

# %%
# Chart - 12 visualization codeplt.figure(figsize = (8,5))

hotel_wise_revenue = dataset1.groupby('hotel')['revenue'].sum()
hotel_wise_revenue
# Out:
# hotel
# City Hotel      18774101.54
# Resort Hotel    15686837.77
# Name: revenue, dtype: float64

# %%
plt.figure(figsize = (8,5))
ax = hotel_wise_revenue.plot(kind = 'bar', color = ('b', 'y'))
plt.xlabel("Hotel", fontdict={'fontsize': 12, 'fontweight' : 5, 'color' : 'Brown'})
plt.ylabel("Total Revenue", fontdict={'fontsize': 12, 'fontweight' : 5, 'color' : 'Brown'} )
plt.title("Total Revenue", fontdict={'fontsize': 12, 'fontweight' : 5, 'color' : 'Green'} )
# Out:
# Text(0.5, 1.0, 'Total Revenue')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ## I have used this chart to represent the total revenue hotel wise.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## I found out that the total revenue of city hotel was 18,774,101  and resort hotel was 15,686,837

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# # Gained insights on the revenue figures of the city hotel (18,774,101) and resort hotel (15,686,837) can potentially create a positive business impact by:
#
# ## Identifying Revenue Sources: Understanding the contribution of each hotel to the overall revenue helps in allocating resources effectively and focusing on the hotel that generates higher revenue.
#
# ## Targeted Marketing Strategies: Analyzing customer preferences and booking patterns can enable targeted marketing efforts to attract more customers and increase revenue.
#
# # However, it is important to consider potential negative growth factors:
#
# ##Revenue Disparity: If the resort hotel consistently lags behind the city hotel in revenue, it may indicate underperformance or challenges in attracting customers, leading to negative growth.
#
# ##Seasonal Variations: Fluctuations in revenue due to seasonal factors need to be considered. If the revenue difference is solely based on seasonal variations, it may not indicate negative growth.

# %% [markdown]
# #### Chart - 13

# %% [markdown]
# # **13) Average ADR(Average daily Rate) of hotels**

# %%
average_adr = dataset1.groupby('hotel')['adr'].mean()
average_adr
plt.subplots(figsize=(8, 5))
average_adr.plot(kind = 'barh', color = ('g', 'r'))
plt.xlabel("Average ADR", fontdict={'fontsize': 12, 'fontweight' : 5, 'color' : 'Brown'})
plt.ylabel("Hotel Name", fontdict={'fontsize': 12, 'fontweight' : 5, 'color' : 'Brown'} )
plt.title("Average ADR of Hotel", fontdict={'fontsize': 12, 'fontweight' : 5, 'color' : 'Green'} )
# Out:
# Text(0.5, 1.0, 'Average ADR of Hotel')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ## To specify the average ADR for both hotels

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## As we can see the average ADR of City hotel is higher than Resort hotel, so the profit and revenue will be higher for city hotel

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ## Here, we can do more advertising for City hotel to get more customer, which result higher profit

# %% [markdown]
# Chart - 14

# %% [markdown]
# # **14) Relationship between adr and total stay**

# %%
# Groupby adr,total,stay,hotel,
adr_vs_stay = dataset1.groupby(['total_stays', 'adr','hotel']).agg('count').reset_index()
adr_vs_stay = adr_vs_stay.iloc[:, :3]
adr_vs_stay = adr_vs_stay.rename(columns={'is_canceled':'Number of stays'})
adr_vs_stay=adr_vs_stay[:18000]
adr_vs_stay
# Out:
#        total_stays     adr         hotel
# 0                0    0.00    City Hotel
# 1                0    0.00  Resort Hotel
# 2                1    0.00    City Hotel
# 3                1    0.00  Resort Hotel
# 4                1    1.00    City Hotel
# ...            ...     ...           ...
# 17995            7  210.86  Resort Hotel
# 17996            7  211.00  Resort Hotel
# 17997            7  211.03  Resort Hotel
# 17998            7  211.16  Resort Hotel
# 17999            7  211.20  Resort Hotel
#
# [18000 rows x 3 columns]

# %%
#plot line chart
plt.figure(figsize=(16,8))
sns.lineplot(x='total_stays',y='adr',data=adr_vs_stay)
plt.title('Relationship between adr and total stay')
# Out:
# Text(0.5, 1.0, 'Relationship between adr and total stay')

# %% [markdown]
# ## **Conclusion = As the total stay increases the adr also increases.**

# %%
dataset1.drop(dataset1[dataset1['adr'] > 5000].index, inplace = True)
plt.figure(figsize=(16,8))
sns.scatterplot(x=dataset1['total_stays'],y=dataset1['adr'])
plt.title('Relationship between  adr and total stays')
# Out:
# Text(0.5, 1.0, 'Relationship between  adr and total stays')

# %% [markdown]
# ## observation: The people who stay for more number of days in a hotel their ADR is comparatively lower than the guests who stay in the hotel for fewer days.

# %% [markdown]
# #### Chart - 15 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize = [15,6])
sns.heatmap(dataset1.corr(), annot = True ,cmap = 'coolwarm')
plt.title('Co-relation of the columns')
# Out:
# <ipython-input-62-6d9b3d09a21f>:3: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# Text(0.5, 1.0, 'Co-relation of the columns')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ## The color-coding of the cells makes it easy to identify relationships between variables at a glance. Correlation heatmaps are used to find both linear and nonlinear relationships between variables

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## 1) is_canceled and same_room_alloted_or_not are negatively corelated. That means customer is unlikely to cancel his bookings if he don't get the same room as per reserved room. We have visualized it above.
# ## 2) lead_time and total_stay is positively corelated.That means more is the stay of cutsomer more will be the lead time.
# ## 3)adults,childrens and babies are corelated to each other. That means more the people more will be adr.
# ## 4) is_repeated guest and previous bookings not canceled has strong corelation. may be repeated guests are not more likely to cancel their bookings.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# 1. For hotel business to flourish few things which we need to consider is high revenue generation, customers satisfaction and employeee retention.
# 2. 27% cancellation rate so We need to find the causes of cancellation and try to minimize it as much as possible.
# 3. We will be able to increase efficiency and revenue by showing the client which are the months that are high in revenue generation by pie chart distribution.
# 4. From the above insights we get to know that agent no. 9 has done the greatest number of bookings, we can get an insight of agent no.9's working method and the kind of skills he aquires, We can train other agents with the help of agent no.9's expertise which can result in the improvement of the performance of agents who are not performing well.
# 5. Repeated guests are very few which is only 3.9 %. In order to retain the guests management should take feedbacks from guests and try to imporve the services.
# 6. As we can see that roughly 9%-10% guests need parking spaces. Keeping that in mind the hotels can efficiently manage the alloted parking space in the hotel.
# 7. Outliers like higher the visitor then adr has reduced drastically was shown in scattered plot so in off season client can engage with offices for bulk booking this will aslo help extra revenue generation.
# 8. We where also able to co relate the values showing the max and min percentage between them so that the percenytage lying those numbers can be enhanced by various medium.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1.	City hotels are the most preferred hotel type by the guests. We can say City hotel is the busiest hotel.
# 2.	27.5 % bookings were got cancelled out of all the bookings.
# 3.	Only 3.9 % people were revisited the hotels. Rest 96.1 % were new guests. Thus retention rate is low.
# 4.	The percentage of 0 changes made in the booking was more than 82 %.  Percentage of Single changes made was about 10%.
# 5.	Most of the customers (91.6%) do not require car parking spaces.
# 6.	79.1 % bookings were made through TA/TO (travel agents/Tour operators).
# 7.	BB( Bed & Breakfast) is the most preferred  type of meal by the guests.
# 8.	Maximum number of guests were from Portugal, i.e. more than 25000 guests.
# 9.	Most of the bookings for City hotels and Resort hotel were happened in 2016.
# 10.	Average ADR for city hotel is high as compared to resort hotels. These City hotels are generating more revenue than the resort hotels.
# 11.	Booking cancellation rate is high for City hotels which almost 30 %.
# 12.	Average lead time for resort hotel is high.
# 13.	Waiting time period for City hotel is high as compared to resort hotels. That means city hotels are much busier than Resort hotels.
# 14.	Resort hotels have the most repeated guests.
# 15.	Optimal stay in both the type hotel is less than 7 days. Usually people stay for a week.
# 16.	Almost 19 % people did not cancel their bookings even after not getting the same room which they reserved while booking hotel. Only 2.5 % people cancelled the booking.
